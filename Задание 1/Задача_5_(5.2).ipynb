# %% [markdown]
# # Богданов Александр Иванович, Б05-003

# %% [markdown]
# ## Задача 5.2

# %% [markdown]
# Выборка: архив записей голоса
#
# Требуется:
#
# 1. Отобрать записи, соответствующие странам с минимум 30 респонеднтами в выборке;
# 2. Получить сумму zero-crossing по каждой из записей;
# 3. Провести ANOVA-анализ по аттрибутам родного языка, пола и возраста для уровня значимости 0.15. Дискретность признака zero-crossing игнорировать.

# %% [markdown]
# ## Решение|

# %%
import pandas as pd
import numpy as np
import librosa
from pathlib import Path
from statsmodels.formula.api import ols
import statsmodels.api as sm

# %% [markdown]
# Загрузим данные.

# %%
data = pd.read_csv('data/speakers_all.csv')
data
# Out:
#        age  age_onset              birthplace  filename native_language  \
# 0     24.0       12.0         koussi, senegal   balanta         balanta
# 1     18.0       10.0          buea, cameroon  cameroon        cameroon
# 2     48.0        8.0  hong, adamawa, nigeria  fulfulde        fulfulde
# 3     42.0       42.0   port-au-prince, haiti   haitian         haitian
# 4     40.0       35.0   port-au-prince, haiti   haitian         haitian
# ...    ...        ...                     ...       ...             ...
# 2167  46.0        5.0          lagos, nigeria   yoruba3          yoruba
# 2168  46.0       12.0          lagos, nigeria   yoruba4          yoruba
# 2169  47.0        2.0         ibadan, nigeria   yoruba5          yoruba
# 2170  31.0        1.0     bethel, alaska, usa    yupik1           yupik
# 2171  24.0       14.0      bulawayo, zimbabwe     zulu1            zulu
#
#          sex  speakerid   country  file_missing?  Unnamed: 9  Unnamed: 10  \
# 0       male        788   senegal           True         NaN          NaN
# 1       male       1953  cameroon           True         NaN          NaN
# 2       male       1037   nigeria           True         NaN          NaN
# 3       male       1165     haiti           True         NaN          NaN
# 4       male       1166     haiti           True         NaN          NaN
# ...      ...        ...       ...            ...         ...          ...
# 2167  female        766   nigeria          False         NaN          NaN
# 2168    male        851   nigeria          False         NaN          NaN
# 2169  female       2023   nigeria          False         NaN          NaN
# 2170  female        571       usa          False         NaN          NaN
# 2171  female        406  zimbabwe          False         NaN          NaN
#
#      Unnamed: 11
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2167         NaN
# 2168         NaN
# 2169         NaN
# 2170         NaN
# 2171         NaN
#
# [2172 rows x 12 columns]

# %% [markdown]
# Удалим ненужные слобцы и строки с потерянными файлами.

# %%
data = data[data['file_missing?'] == False]

data = data.drop(['Unnamed: 9',
                  'Unnamed: 10',
                  'Unnamed: 11',
                  'file_missing?'], axis=1)
data
# Out:
#        age  age_onset                         birthplace    filename  \
# 32    27.0        9.0             virginia, south africa  afrikaans1
# 33    40.0        5.0             pretoria, south africa  afrikaans2
# 34    43.0        4.0  pretoria, transvaal, south africa  afrikaans3
# 35    26.0        8.0             pretoria, south africa  afrikaans4
# 36    19.0        6.0            cape town, south africa  afrikaans5
# ...    ...        ...                                ...         ...
# 2167  46.0        5.0                     lagos, nigeria     yoruba3
# 2168  46.0       12.0                     lagos, nigeria     yoruba4
# 2169  47.0        2.0                    ibadan, nigeria     yoruba5
# 2170  31.0        1.0                bethel, alaska, usa      yupik1
# 2171  24.0       14.0                 bulawayo, zimbabwe       zulu1
#
#      native_language     sex  speakerid       country
# 32         afrikaans  female          1  south africa
# 33         afrikaans    male          2  south africa
# 34         afrikaans    male        418  south africa
# 35         afrikaans    male       1159  south africa
# 36         afrikaans    male       1432  south africa
# ...              ...     ...        ...           ...
# 2167          yoruba  female        766       nigeria
# 2168          yoruba    male        851       nigeria
# 2169          yoruba  female       2023       nigeria
# 2170           yupik  female        571           usa
# 2171            zulu  female        406      zimbabwe
#
# [2140 rows x 8 columns]

# %% [markdown]
# Отберем записи, соответствующие странам с минимум 30 респонеднтами в выборке.

# %%
country_counts = data['country'].value_counts()
selected_countries = country_counts[country_counts >= 30].index
data = data[data['country'].isin(selected_countries)]
data
# Out:
#        age  age_onset                  birthplace   filename native_language  \
# 50    20.0        5.0       addis ababa, ethiopia   amharic1         amharic
# 51    29.0       19.0            gonder, ethiopia  amharic10         amharic
# 52    24.0       17.0       addis ababa, ethiopia  amharic11         amharic
# 53    26.0       15.0       addis ababa, ethiopia  amharic12         amharic
# 54    28.0        6.0       addis ababa, ethiopia  amharic13         amharic
# ...    ...        ...                         ...        ...             ...
# 2157  23.0       10.0       zhuzhou, hunan, china     xiang4           xiang
# 2158  19.0       13.0             yakutsk, russia     yakut1           yakut
# 2161  78.0        6.0  winnipeg, manitoba, canada   yiddish2         yiddish
# 2162  52.0        5.0     brooklyn, new york, usa   yiddish3         yiddish
# 2170  31.0        1.0         bethel, alaska, usa     yupik1           yupik
#
#          sex  speakerid   country
# 50    female          6  ethiopia
# 51    female        998  ethiopia
# 52    female       1129  ethiopia
# 53    female       1130  ethiopia
# 54    female       1131  ethiopia
# ...      ...        ...       ...
# 2157  female       2163     china
# 2158  female       1252    russia
# 2161  female        405    canada
# 2162    male       1161       usa
# 2170  female        571       usa
#
# [1045 rows x 8 columns]

# %% [markdown]
# Получим сумму zero-crossing по каждой из записей.

# %%
def compute_zero_crossing(file_name):
    audio, _ = librosa.load(Path('data', 'recordings', f'{file_name}.mp3'))
    zero_crossings = librosa.zero_crossings(audio, pad=False)
    return sum(zero_crossings)

# %%
data.loc[:, 'zero_crossing'] = data['filename'].apply(compute_zero_crossing)

# %%
data
# Out:
#        age  age_onset                  birthplace   filename native_language  \
# 50    20.0        5.0       addis ababa, ethiopia   amharic1         amharic
# 51    29.0       19.0            gonder, ethiopia  amharic10         amharic
# 52    24.0       17.0       addis ababa, ethiopia  amharic11         amharic
# 53    26.0       15.0       addis ababa, ethiopia  amharic12         amharic
# 54    28.0        6.0       addis ababa, ethiopia  amharic13         amharic
# ...    ...        ...                         ...        ...             ...
# 2157  23.0       10.0       zhuzhou, hunan, china     xiang4           xiang
# 2158  19.0       13.0             yakutsk, russia     yakut1           yakut
# 2161  78.0        6.0  winnipeg, manitoba, canada   yiddish2         yiddish
# 2162  52.0        5.0     brooklyn, new york, usa   yiddish3         yiddish
# 2170  31.0        1.0         bethel, alaska, usa     yupik1           yupik
#
#          sex  speakerid   country  zero_crossing
# 50    female          6  ethiopia          68406
# 51    female        998  ethiopia          73988
# 52    female       1129  ethiopia          81180
# 53    female       1130  ethiopia          64650
# 54    female       1131  ethiopia         104104
# ...      ...        ...       ...            ...
# 2157  female       2163     china          81333
# 2158  female       1252    russia          50062
# 2161  female        405    canada          63399
# 2162    male       1161       usa          52182
# 2170  female        571       usa          48672
#
# [1045 rows x 9 columns]

# %% [markdown]
# Проведем ANOVA анализ

# %%
lm = ols('zero_crossing ~ age * C(sex) * C(native_language)', data=data).fit()
table = sm.stats.anova_lm(lm, typ=1)
table
# Out:
#                                   df        sum_sq       mean_sq          F  \
# C(sex)                           1.0  1.833897e+10  1.833897e+10  25.390356
# C(native_language)              55.0  2.732250e+11  4.967728e+09   6.877833
# C(sex):C(native_language)       55.0  1.076747e+11  1.957721e+09   2.710470
# age                              1.0  1.522574e+10  1.522574e+10  21.080076
# age:C(sex)                       1.0  3.298890e+08  3.298890e+08   0.456732
# age:C(native_language)          55.0  6.406172e+10  1.164759e+09   1.612612
# age:C(sex):C(native_language)   55.0  3.104753e+10  5.645005e+08   0.781553
# Residual                       914.0  6.601648e+11  7.222809e+08        NaN
#
#                                      PR(>F)
# C(sex)                         5.643279e-07
# C(native_language)             4.971828e-40
# C(sex):C(native_language)      1.251458e-09
# age                            5.020936e-06
# age:C(sex)                     4.993261e-01
# age:C(native_language)         3.796413e-03
# age:C(sex):C(native_language)  8.751763e-01
# Residual                                NaN

# %%
table[table['PR(>F)'] < 0.15]
# Out:
#                              df        sum_sq       mean_sq          F  \
# C(sex)                      1.0  1.833897e+10  1.833897e+10  25.390356
# C(native_language)         55.0  2.732250e+11  4.967728e+09   6.877833
# C(sex):C(native_language)  55.0  1.076747e+11  1.957721e+09   2.710470
# age                         1.0  1.522574e+10  1.522574e+10  21.080076
# age:C(native_language)     55.0  6.406172e+10  1.164759e+09   1.612612
#
#                                  PR(>F)
# C(sex)                     5.643279e-07
# C(native_language)         4.971828e-40
# C(sex):C(native_language)  1.251458e-09
# age                        5.020936e-06
# age:C(native_language)     3.796413e-03

# %% [markdown]
# Как мы видим zero-crosing зависит от возраста, родного языка, пола, а также в данной выборке есть зависимость, пола и родного языка, а также зависимость возраста и родного языка - выборка не сбалансирована.
